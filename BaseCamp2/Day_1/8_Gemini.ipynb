# %% [markdown]
# ### Gemini Usage for LLM ###
# **Library Need**
# To use the APIs provided by the Geimi platform, the library 'Google GenAI' is required.
# Ensure to have performed 'pip install google-genai'
# The API key from your Google AI account would be required to execute this code

# %%
# Import required class from Google
from google import genai
from google.genai import types
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
client = genai.Client()

# Client = genai.Client (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >We try Gemini to get response from LLM
# >Note the differece in terms of API

# %%
response = client.models.generate_content(
                model="gemini-2.0-flash", 
                contents="How do I learn python?"
            )
print(response.text)
# Out:
# Learning Python can be a rewarding and valuable skill! Here's a structured approach to guide you through the process, covering various resources and methods:
#
# **1. Define Your Goals:**
#
# *   **Why do you want to learn Python?**  Understanding your motivation will help you stay focused and choose the right learning path. Are you interested in:
#     *   **Web development (backend)?** (Frameworks like Django or Flask)
#     *   **Data science and analysis?** (Libraries like Pandas, NumPy, Scikit-learn)
#     *   **Machine learning and AI?** (TensorFlow, PyTorch)
#     *   **Scripting and automation?** (System administration tasks, file processing)
#     *   **Game development?** (Pygame)
#     *   **General programming skills?**
#
# **2. Choose Your Learning Resources:**
#
# Here's a breakdown of excellent resources, categorized for different learning styles:
#
# *   **Interactive Tutorials/Platforms (Hands-on):**
#     *   **Codecademy (Python 3):** A great starting point for beginners.  Provides immediate feedback and covers the basics comprehensively.
#     *   **DataCamp:** Excellent for data science-focused Python learning.  Offers interactive courses on Pandas, NumPy, and other relevant libraries.
#     *   **LeetCode/HackerRank:** Practice coding problems to improve your problem-solving skills and prepare for technical interviews. (Best after you have some foundational knowledge)
#     *   **Codewars:** Similar to LeetCode/HackerRank, but with a gamified approach.
#     *   **Real Python:** Comprehensive tutorials and courses on various Python topics, from beginner to advanced. (Some content is free, some requires a subscription)
#     *   **freeCodeCamp.org:** Offers a free, comprehensive Python curriculum.
#     *   **Google's Python Class:** Well-structured and free, covering the basics and practical examples. (Uses Python 2, but the core concepts are still relevant). Convert to Python 3 syntax as you learn.
#     *   **CheckiO:** Gamified learning environment where you solve coding problems using Python.
#
# *   **Online Courses (More structured):**
#     *   **Coursera:** Offers courses from universities and institutions on Python, often with certificates. (e.g., "Python for Everybody" by the University of Michigan)
#     *   **edX:** Similar to Coursera, with courses from universities worldwide.
#     *   **Udemy:** Wide variety of Python courses, often at discounted prices. (Look for highly-rated courses with recent updates)
#     *   **Fast.ai:**  Focused on practical machine learning with Python.  Suitable for learners with some Python experience.
#
# *   **Books (In-depth and detailed):**
#     *   **"Python Crash Course" by Eric Matthes:** Excellent for beginners, covering the fundamentals and building simple projects.
#     *   **"Automate the Boring Stuff with Python" by Al Sweigart:** Focuses on practical scripting and automation tasks. Freely available online.
#     *   **"Think Python" by Allen B. Downey:** A more conceptual and mathematically oriented approach. Also freely available online.
#     *   **"Fluent Python" by Luciano Ramalho:** A deep dive into advanced Python concepts for experienced programmers.
#     *   **"Effective Python" by Brett Slatkin:**  Teaches you how to write idiomatic and efficient Python code.
#
# *   **YouTube Channels:**
#     *   **Corey Schafer:** Clear and well-explained Python tutorials on various topics.
#     *   **Sentdex:** Covers a wide range of topics, including data science, machine learning, and game development.
#     *   **freeCodeCamp.org (YouTube Channel):**  Offers long-form courses on various programming languages, including Python.
#     *   **Programming with Mosh:** Another excellent channel with Python tutorials.
#
# *   **Official Documentation:**
#     *   **Python Documentation:** The definitive resource for Python, including the language reference, standard library documentation, and tutorials. While it can be dense, it's essential for understanding the details.
#
# **3. Create a Learning Plan:**
#
# *   **Start with the Basics:**  Don't jump into advanced topics right away. Focus on understanding:
#     *   **Syntax:** Variables, data types (integers, floats, strings, booleans, lists, tuples, dictionaries, sets), operators.
#     *   **Control Flow:** `if`, `else`, `elif` statements, `for` and `while` loops.
#     *   **Functions:** Defining and calling functions, arguments, return values.
#     *   **Modules:** Importing and using modules, the Python Standard Library.
#     *   **Object-Oriented Programming (OOP):**  Classes, objects, inheritance, polymorphism (optional to start, but important later).
#     *   **Error Handling:**  `try`, `except` blocks.
#
# *   **Set Realistic Goals:**  Don't try to learn everything at once. Break down your learning into smaller, manageable chunks.  For example:
#     *   **Week 1:** Learn about variables, data types, and basic operators.
#     *   **Week 2:** Learn about control flow (if/else statements, loops).
#     *   **Week 3:** Learn about functions and modules.
#     *   **Week 4:** Build a simple project (e.g., a calculator, a to-do list).
#
# *   **Practice Consistently:**  Coding is a skill that requires practice.  Try to code every day, even if it's just for 30 minutes.
#
# **4.  Practice, Practice, Practice! (The Most Important Step)**
#
# *   **Work Through Examples:**  Don't just read about code; actually type it in and run it.  Experiment with different variations.
# *   **Solve Coding Challenges:**  Use platforms like LeetCode, HackerRank, and Codewars to practice your problem-solving skills.
# *   **Build Projects:**  The best way to learn is to build things.  Start with small projects and gradually increase the complexity.  Examples:
#     *   **Simple Calculator**
#     *   **To-Do List Application**
#     *   **Number Guessing Game**
#     *   **Simple Web Scraper**
#     *   **Text-Based Adventure Game**
#     *   **Basic Data Analysis Script**
# *   **Contribute to Open Source Projects:**  Once you have some experience, consider contributing to open-source projects.  This is a great way to learn from experienced developers and improve your skills.
#
# **5.  Find a Community and Get Help:**
#
# *   **Join Online Forums and Communities:**
#     *   **Stack Overflow:** A question-and-answer website for programmers.
#     *   **Reddit:** Subreddits like r/learnpython, r/python, and r/datascience.
#     *   **Discord Servers:** Many Python communities have Discord servers where you can chat with other learners and ask questions.
# *   **Attend Meetups and Workshops:**  Look for local Python meetups and workshops in your area.
# *   **Find a Mentor:**  If possible, find a mentor who can guide you and provide feedback.
#
# **6. Key Concepts to Focus On:**
#
# *   **Data Structures:** Understand and use lists, tuples, dictionaries, and sets effectively.  Know when to use which data structure.
# *   **List Comprehensions:** A concise way to create lists in Python.
# *   **Generators:**  A memory-efficient way to create iterators.
# *   **Decorators:**  A way to modify the behavior of functions and methods.
# *   **Context Managers:**  A way to manage resources (e.g., files) using the `with` statement.
# *   **Regular Expressions:**  For pattern matching and text manipulation.
#
# **7.  Version Control (Git):**
#
# *   Learn how to use Git for version control.  This is essential for collaborating with other developers and managing your code.  GitHub is a popular platform for hosting Git repositories.
#
# **Tips for Success:**
#
# *   **Be Patient:** Learning takes time and effort. Don't get discouraged if you don't understand something right away.
# *   **Be Persistent:** Keep practicing, even when you feel like giving up.
# *   **Stay Curious:** Explore different aspects of Python and find what interests you.
# *   **Write Clean Code:**  Follow the PEP 8 style guide for Python code.  This will make your code more readable and maintainable.
# *   **Document Your Code:**  Write comments to explain what your code does.
#
# **Example Learning Path (Beginner to Intermediate):**
#
# 1.  **Codecademy's Python 3 Course:**  Covers the basics of syntax, data types, control flow, functions, and modules.
# 2.  **"Automate the Boring Stuff with Python":** Learn practical scripting and automation skills.  Build projects like a web scraper and a spreadsheet manipulator.
# 3.  **Choose a Specialization:** Based on your interests, choose a specialization like web development (Django/Flask), data science (Pandas/NumPy), or machine learning (Scikit-learn/TensorFlow).
# 4.  **Take a Course or Read a Book on Your Chosen Specialization:**  For example, if you're interested in data science, take a course on Pandas and NumPy.
# 5.  **Build Projects in Your Chosen Specialization:**  For example, if you're interested in data science, build a project that analyzes a dataset.
# 6.  **Contribute to Open Source Projects:**  Contribute to a project in your chosen specialization.
#
# By following these steps and consistently practicing, you'll be well on your way to becoming a proficient Python programmer!  Good luck!

# %%
# There is a specific instruction given 
Instruction = "Continue the statement and make it 50 words"
Statement  = "When Trump says Tariff, the world ..."
# Statement  = "They say technology is for people, but ..."

# Invoke multiple times ...
# ?? What do we expect 
for i in range (5):
    
    response = client.models.generate_content(
                    model="gemini-2.0-flash",
                    config =types.GenerateContentConfig(
                                system_instruction=Instruction,),
                    contents =Statement
    )

    print(response.text)
# Out:
# When Trump says "Tariff," the world braces for impact. Global markets often react with volatility, as businesses anticipate increased costs and potential trade wars. Negotiating positions shift, and international relationships can become strained, all while consumers potentially face higher prices.
#
# When Trump says "Tariff," the world braces for economic shifts. Businesses scramble to assess potential cost increases, trade partners threaten retaliation, and global markets react with uncertainty, anticipating disruptions in established supply chains and potential inflationary pressures that could impact consumers worldwide.
#
# When Trump says "Tariff," the world braces for impact. Nations scramble to assess the potential economic consequences, anticipating trade wars, disrupted supply chains, and increased costs for consumers. Uncertainty grips global markets as businesses and governments alike react to the potential shifts in international trade dynamics.
#
# When Trump says "Tariff," the world holds its breath. Nations brace for potential trade wars, economic disruption, and altered supply chains. Businesses scramble to reassess costs and strategies, fearing price increases and reduced competitiveness in the global market, triggering uncertainty and market volatility.
#
# When Trump says "Tariff," the world holds its breath, anticipating potential trade wars. Businesses scramble to assess impacts on supply chains and consumer prices, while governments brace for retaliatory measures and global economic instability. Uncertainty reigns as markets react to the shifting landscape of international trade.
